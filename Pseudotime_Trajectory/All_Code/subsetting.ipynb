# %%
import anndata
import pandas as pd

# %%
pwd
# Out:
# '/Users/marianasierra/Desktop/Group_11'

# %%
ys_dict = {"path": "original_data/ys_portal_object_20221208.h5ad", "type": "LVL2", "val": "MAST_CELL", "writes": "ys_mast_cells.h5ad"}
sum_dict = {"human":human_dict, "ys":ys_dict}

# %%
# CHANGE: select between "human" and "ys" for subsetting
# no need to change everything else
dict_to_use = sum_dict["ys"]

# %%
#adata_path = "ys_portal_object_20221208.h5ad"  # yolk sac

adata_path = dict_to_use["path"]
adata = anndata.read_h5ad(adata_path)
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 169494 × 37318
#     obs: 'component', 'stage', 'sex', 'sort.ids', 'fetal.ids', 'orig.dataset', 'sequencing.type', 'lanes', 'LVL1', 'LVL2', 'LVL3'
#     obsm: 'X_umap'

# %%
adata.obs.head(n=10)
# Out:
#                                 component stage   sex sort.ids  fetal.ids  \
# Wang_et_al_AAACCTGAGACCTTTG_1-0  Membrane  CS10  Male    Total  Wang_CS10
# Wang_et_al_AAACCTGCACTTAAGC_1-0  Membrane  CS10  Male    Total  Wang_CS10
# Wang_et_al_AAACCTGGTAACGACG_1-0  Membrane  CS10  Male    Total  Wang_CS10
# Wang_et_al_AAACCTGGTCAAAGAT_1-0  Membrane  CS10  Male    Total  Wang_CS10
# Wang_et_al_AAACCTGGTCCGAAGA_1-0  Membrane  CS10  Male    Total  Wang_CS10
# Wang_et_al_AAACCTGGTCCGCTGA_1-0  Membrane  CS10  Male    Total  Wang_CS10
# Wang_et_al_AAACCTGGTCTGGAGA_1-0  Membrane  CS10  Male    Total  Wang_CS10
# Wang_et_al_AAACCTGGTGTGAATA_1-0  Membrane  CS10  Male    Total  Wang_CS10
# Wang_et_al_AAACCTGTCTGTTGAG_1-0  Membrane  CS10  Male    Total  Wang_CS10
# Wang_et_al_AAACGGGAGACTAGGC_1-0  Membrane  CS10  Male    Total  Wang_CS10
#
#                                                    orig.dataset  \
# Wang_et_al_AAACCTGAGACCTTTG_1-0  Wang_et_al_Cell_Stem Cell_2021
# ...

# %%
adata.raw

# %%
#mast_cells = adata[adata.obs['cell_type'] == 'mast cell']  # human
#mast_cells = adata[adata.obs['LVL2'] == 'MAST_CELL']  # yolk sac
mast_cells = adata[adata.obs[dict_to_use["type"]] == dict_to_use["val"]]

# %%
mast_cells.obs.head(n=10)
# Out:
#                                                    component stage     sex  \
# Wang_et_al_ACACCGGGTCCAAGTT_1-0                     Membrane  CS10    Male
# Wang_et_al_ACGAGGATCTGCAGTA_1-0                     Membrane  CS10    Male
# Wang_et_al_ATCGAGTGTCGAGTTT_1-0                     Membrane  CS10    Male
# Wang_et_al_CAGCCGAGTAGGGTAC_1-0                     Membrane  CS10    Male
# F32_Yolksac_Total_FCAImmP7316900_CATCAAGTCTTACC...  Contents  CS22  Female
# F32_Yolksac_Total_FCAImmP7316900_CCCATACAGCTCTC...  Contents  CS22  Female
# F32_Yolksac_Total_FCAImmP7316900_CGACTTCCACCATG...  Contents  CS22  Female
# F32_Yolksac_Total_FCAImmP7316900_GGACATTTCGCGTA...  Contents  CS22  Female
# F32_Yolksac_Total_FCAImmP7316900_GGGCACTTCACTTA...  Contents  CS22  Female
# F32_Yolksac_Total_FCAImmP7316900_GGGTTGCGTTTGAC...  Contents  CS22  Female
#
#                                                    sort.ids  fetal.ids  \
# ...

# %%
#type(mast_cells)
mast_cells
# Out:
# View of AnnData object with n_obs × n_vars = 354 × 37318
#     obs: 'component', 'stage', 'sex', 'sort.ids', 'fetal.ids', 'orig.dataset', 'sequencing.type', 'lanes', 'LVL1', 'LVL2', 'LVL3'
#     obsm: 'X_umap'

# %%
# save 
#mast_cells.write_h5ad('human_mast_cells.h5ad')  # human
#mast_cells.write_h5ad('ys_mast_cells.h5ad') # yolk sac

mast_cells.write_h5ad(dict_to_use["writes"])
