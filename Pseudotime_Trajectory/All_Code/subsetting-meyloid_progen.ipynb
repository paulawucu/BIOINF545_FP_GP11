# %%
import anndata
import pandas as pd

# %%
pwd
# Out:
# '/Users/marianasierra/Desktop/Group_11/meyloid_data'

# %%
adata_path = "/Users/marianasierra/Desktop/Group_11/meyloid_data/ys_portal_object_20221208.h5ad"
adata = anndata.read_h5ad(adata_path)
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 169494 × 37318
#     obs: 'component', 'stage', 'sex', 'sort.ids', 'fetal.ids', 'orig.dataset', 'sequencing.type', 'lanes', 'LVL1', 'LVL2', 'LVL3'
#     obsm: 'X_umap'

# %%
adata.obs.head(n=10)
# Out:
#                                 component stage   sex sort.ids  fetal.ids  \
# Wang_et_al_AAACCTGAGACCTTTG_1-0  Membrane  CS10  Male    Total  Wang_CS10
# Wang_et_al_AAACCTGCACTTAAGC_1-0  Membrane  CS10  Male    Total  Wang_CS10
# Wang_et_al_AAACCTGGTAACGACG_1-0  Membrane  CS10  Male    Total  Wang_CS10
# Wang_et_al_AAACCTGGTCAAAGAT_1-0  Membrane  CS10  Male    Total  Wang_CS10
# Wang_et_al_AAACCTGGTCCGAAGA_1-0  Membrane  CS10  Male    Total  Wang_CS10
# Wang_et_al_AAACCTGGTCCGCTGA_1-0  Membrane  CS10  Male    Total  Wang_CS10
# Wang_et_al_AAACCTGGTCTGGAGA_1-0  Membrane  CS10  Male    Total  Wang_CS10
# Wang_et_al_AAACCTGGTGTGAATA_1-0  Membrane  CS10  Male    Total  Wang_CS10
# Wang_et_al_AAACCTGTCTGTTGAG_1-0  Membrane  CS10  Male    Total  Wang_CS10
# Wang_et_al_AAACGGGAGACTAGGC_1-0  Membrane  CS10  Male    Total  Wang_CS10
#
#                                                    orig.dataset  \
# Wang_et_al_AAACCTGAGACCTTTG_1-0  Wang_et_al_Cell_Stem Cell_2021
# ...

# %%
adata.raw

# %%
# nnData object
meyloid = ['MAST_CELL','MEMP',"PRIM_HSPC_1", "PRIM_HSPC_2", "DEF_HSPC_2", "DEF_HSPC_1", "HSPC_1", "HSPC_2",'CMP',"EO_BASO_MAST_PRECURSOR"]

# Create boolean mask indicating desired cell types
cell_type_mask = adata.obs['LVL3'].isin(meyloid)

# Apply the mask to filter the AnnData object
filtered_adata = adata[cell_type_mask]

filtered_adata.obs.head(n=50)
# Out:
#                                 component stage   sex sort.ids  fetal.ids  \
# Wang_et_al_AAACCTGCACTTAAGC_1-0  Membrane  CS10  Male    Total  Wang_CS10
# Wang_et_al_AAACGGGTCCCATTTA_1-0  Membrane  CS10  Male    Total  Wang_CS10
# Wang_et_al_AAAGATGGTTGGACCC_1-0  Membrane  CS10  Male    Total  Wang_CS10
# Wang_et_al_AAAGTAGAGTGGTCCC_1-0  Membrane  CS10  Male    Total  Wang_CS10
# Wang_et_al_AACACGTGTTGATTCG_1-0  Membrane  CS10  Male    Total  Wang_CS10
# Wang_et_al_AACGTTGAGGGTGTTG_1-0  Membrane  CS10  Male    Total  Wang_CS10
# Wang_et_al_AACTCAGCAATGGACG_1-0  Membrane  CS10  Male    Total  Wang_CS10
# Wang_et_al_AACTGGTCAGCTTCGG_1-0  Membrane  CS10  Male    Total  Wang_CS10
# Wang_et_al_AAGACCTTCACAACGT_1-0  Membrane  CS10  Male    Total  Wang_CS10
# Wang_et_al_AATCCAGAGTACTTGC_1-0  Membrane  CS10  Male    Total  Wang_CS10
# Wang_et_al_AATCGGTAGCCATCGC_1-0  Membrane  CS10  Male    Total  Wang_CS10
# Wang_et_al_AATCGGTTCAGCGATT_1-0  Membrane  CS10  Male    Total  Wang_CS10
# ...

# %%
#type(mast_cells)
meyloid
# Out:
# ['MAST_CELL',
#  'MEMP',
#  'PRIM_HSPC_1',
#  'PRIM_HSPC_2',
#  'DEF_HSPC_2',
#  'DEF_HSPC_1',
#  'HSPC_1',
#  'HSPC_2',
#  'CMP',
#  'EO_BASO_MAST_PRECURSOR']

# %%
# save 

filtered_adata.write_h5ad('/Users/marianasierra/Desktop/Group_11/meyloid_data/ys_meyloid_data.h5ad')
